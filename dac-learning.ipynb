# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
x = np.arange(1, 2000)
a = 2
b = 9
c = 10
y1 = 600*(x**(-0.32))
y2 = 600*(x**(-0.234))
y3 = 600*(x**(-0.152))
 
plt.figure(figsize=(10,6))
tw = plt.plot(x, y1)
ft = plt.plot(x, y2)
te = plt.plot(x, y3)
hundred = plt.axhline(y=100, color='r', linestyle='-')
plt.title("Cost decrease of DAC at 10/15/20% learning rate")
plt.ylabel("Cost per t/CO2")
plt.xlabel("Mt/y deployed")
plt.legend(['20%','15%','10%'], prop={'size':12})
plt.show()
