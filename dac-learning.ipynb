# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
x = np.arange(1, 2000)
y1 = 600*(x**(-0.152))
y2 = 600*(x**(-0.234))
y3 = 600*(x**(-0.32))
y4 = 600*(x**(-0.515))


 
plt.figure(figsize=(10,6))
tw = plt.plot(x, y1)
ft = plt.plot(x, y2)
te = plt.plot(x, y3)
se = plt.plot(x, y4)
hundred = plt.axhline(y=100, color='r', linestyle='-')
plt.title("Cost decrease of DAC at 10/15/20/30% learning rate")
plt.ylabel("Cost per t/CO2")
plt.xlabel("Mt/y deployed")
plt.legend(['10%','15%','20%','30%'], prop={'size':12})
plt.tight_layout()
plt.savefig("graph.svg")
