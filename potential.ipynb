# %% [markdown]
# Build a plot for the potential of carbon removal for different technologies

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
cost_data = pd.read_excel("potential.xlsx")
cost_data.tail()
# Out:
#      tech  potential            Source  Column1
# 35  BECCS       11.9  Cornelissen 2012      NaN
# 36    DAC        0.5        Brack 2020      NaN
# 37    DAC        5.0        Brack 2020      NaN
# 38  BECCS        2.5      Hanssen 2020      NaN
# 39  BECCS        2.8         Pour 2018      NaN

# %%
spec = dict(x="tech", y="potential", data=cost_data)

plt.figure(figsize=(15,6))
sns.set(font_scale=1.2)
sns.color_palette("tab10")

plot = sns.stripplot(**spec, size=4, jitter=False, s=10, linewidth=1, alpha=.5, hue="Source")
interval = sns.pointplot(**spec, join=False, ci=0, capsize=0.1, scale=0)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),
          fancybox=True, shadow=True, ncol=5)
plot.set(xlabel ="Technology", ylabel = "Potential of sequestration in Gt CO2/y")
plt.tight_layout()
plt.savefig("potential.svg")

# %% [markdown]
# - in summary, more than enough to fulfil the ipcc-defined need
# - but some exclude eachother
# - and not all are realistic or feasible
