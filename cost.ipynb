# %% [markdown]
# Build a plot for the cost of carbon removal for different technologies

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
cost_data = pd.read_excel("cost.xlsx")
cost_data.head()
# Out:
#             tech  price      Source
# 0  Afforestation   49.0  Gorte 2009
# 1  Afforestation  494.0  Gorte 2009
# 2  Afforestation  129.0  Gorte 2009
# 3  Afforestation    7.5    NRC 2015
# 4  Afforestation   22.0    NRC 2015

# %%
spec = dict(x="tech", y="price", data=cost_data)

plt.figure(figsize=(20,6))
sns.set(font_scale=1.2)
sns.color_palette("tab10")

plot = sns.stripplot(**spec, size=4, jitter=False, s=10, linewidth=1, alpha=.5, hue="Source")
interval = sns.pointplot(**spec, join=False, ci=0, capsize=.1, scale=0)
hundred = plt.axhline(y=100, color='r', linestyle='-')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15),
          fancybox=True, shadow=True, ncol=5)
plot.set(xlabel ="Technology", ylabel = "Cost per t/CO2 removed")
# Out:
# [Text(0.5, 0, 'Technology'), Text(0, 0.5, 'Cost per t/CO2 removed')]

# %% [markdown]
# Caveats:
# - not weighted for believability
# - mostly not tested in practice
# - real results could be anywhere inside the given range
# - real consensus only for soil sequestration
