# %% [markdown]
# Build a plot for the cost of carbon removal for different technologies

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
cost_data = pd.read_excel("cost.xlsx")
cost_data.head()
# Out:
#             tech  price      Source  Column1  Unnamed: 4  Unnamed: 5  \
# 0  Afforestation   49.0  Gorte 2009      NaN         NaN         NaN
# 1  Afforestation  494.0  Gorte 2009      NaN         NaN         NaN
# 2  Afforestation  129.0  Gorte 2009      NaN         NaN         NaN
# 3  Afforestation    7.5    NRC 2015      NaN         NaN         NaN
# 4  Afforestation   22.0    NRC 2015      NaN         NaN         NaN
#
#    Unnamed: 6
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
spec = dict(x="tech", y="price", data=cost_data)

plt.figure(figsize=(15.2,6))
sns.set(font_scale=1.2)
sns.color_palette("tab10")

plot = sns.stripplot(**spec, size=4, jitter=False, s=10, linewidth=1, alpha=.5, hue="Source")
interval = sns.pointplot(**spec, join=False, ci=0, capsize=0.1, scale=0)
hundred = plt.axhline(y=100, color='r', linestyle='-')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),
          fancybox=True, shadow=True, ncol=5)
plot.set(xlabel ="Technology", ylabel = "Cost per t/CO2 removed in USD")
plt.tight_layout()
plt.savefig("cost.svg")

# %% [markdown]
# Caveats:
# - not weighted for believability
# - mostly not tested in practice
# - real results could be anywhere inside the given range
# - real consensus only for soil sequestration
# - for dac, significant development and learning effects are expected, which explain the wide range of estimates
# - not exhaustive
# - based on vastly diffeing projections and assumptions
# - servers only as a literature overview
